# %% [markdown]
# ### Model Integration with GROQ, OPEN AI, GEMINI, COHERE

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['COHERE_API_KEY'] = os.getenv('COHERE_API_KEY')
os.environ['GROQ_API_KEY'] = os.getenv('GROQ_API_KEY')
os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')
os.environ['HUGGING_FACE_API_KEY'] = os.getenv('HUGGING_FACE_API_KEY')

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, driven by their **biology, social nature, and cognitive abilities.** It\'s not just random mimicry; it\'s a complex form of communication and social bonding.\n\nHere\'s a breakdown of why parrots talk:\n\n**1. Social Bonding and Mimicry:**\n\n* **Flock Mentality:** Parrots are highly social creatures that live in large flocks in the wild. Communication is crucial for their survival and well-being within these groups.\n* **Learning and Identity:** In their natural habitat, young parrots learn the calls and songs of their flock members. This helps them identify with their group and stay connected. Mimicry is a fundamental part of this learning process.\n* **Strengthening Bonds:** By mimicking sounds and vocalizations, parrots can create and strengthen social bonds with other individuals in their flock. It\'s like saying, "I\'m part of this group, and I understand you."\n\n**2. Cognitive Abilities and Intelligence:**\n\n* **Brain Structure:** Parrots have remarkably large and complex brains for their size, particularly in areas associated with vocal learning and processing.\n* **Vocal Learning:** They possess a specialized vocal apparatus (syrinx) and the neurological capacity to learn and produce a wide range of sounds. This ability is not common in most birds.\n* **Understanding Context (to a degree):** While many parrots are known for simply repeating sounds, some research suggests that certain species, like African Greys, can learn to associate words with objects, actions, and even emotions. They can understand that a certain sound (word) has a specific meaning in a given context.\n\n**3. Survival and Adaptation:**\n\n* **Alarm Calls:** Mimicking the alarm calls of other animals could potentially alert them to danger, although this is less documented for vocal learning in captivity.\n* **Finding Mates/Group Members:** In the wild, distinctive calls can help parrots locate their flock members or potential mates over long distances.\n\n**4. In Captivity: A Different Environment:**\n\n* **Lack of Flock:** When kept as pets, parrots are often separated from their natural flocks. Their innate drive to communicate and bond can then be directed towards their human companions.\n* **Seeking Attention and Interaction:** Talking can be a way for parrots to get attention, express needs (like hunger or a desire to play), or simply interact with their "flock" (their human family).\n* **Boredom and Stimulation:** For intelligent creatures like parrots, talking can also be a way to alleviate boredom and provide mental stimulation.\n\n**5. Individual Variation:**\n\n* **Species Differences:** Not all parrot species are equally adept at talking. African Greys, Amazons, and some Macaws are renowned for their vocal abilities.\n* **Individual Personality:** Just like humans, some individual parrots are more inclined to talk than others, regardless of species.\n\n**In summary, parrots talk because they are:**\n\n* **Highly social creatures** that rely on vocal communication for survival and bonding.\n* **Intelligent animals** with the cognitive capacity for vocal learning.\n* **Equipped with specialized vocal anatomy** that allows them to produce a wide range of sounds.\n\nWhen you hear a parrot talk, you\'re witnessing a sophisticated form of communication that stems from millions of years of evolution and a deep-seated need to connect with their social group.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c040a-f96a-7f21-9baf-46b4cd5b422a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6, 'output_tokens': 702, 'total_tokens': 708, 'input_token_details': {'cache_read': 0}})

# %%
print(response.content)
# Out:
# Parrots talk for a fascinating combination of reasons, driven by their **biology, social nature, and cognitive abilities.** It's not just random mimicry; it's a complex form of communication and social bonding.
#
# Here's a breakdown of why parrots talk:
#
# **1. Social Bonding and Mimicry:**
#
# * **Flock Mentality:** Parrots are highly social creatures that live in large flocks in the wild. Communication is crucial for their survival and well-being within these groups.
# * **Learning and Identity:** In their natural habitat, young parrots learn the calls and songs of their flock members. This helps them identify with their group and stay connected. Mimicry is a fundamental part of this learning process.
# * **Strengthening Bonds:** By mimicking sounds and vocalizations, parrots can create and strengthen social bonds with other individuals in their flock. It's like saying, "I'm part of this group, and I understand you."
#
# **2. Cognitive Abilities and Intelligence:**
#
# * **Brain Structure:** Parrots have remarkably large and complex brains for their size, particularly in areas associated with vocal learning and processing.
# * **Vocal Learning:** They possess a specialized vocal apparatus (syrinx) and the neurological capacity to learn and produce a wide range of sounds. This ability is not common in most birds.
# * **Understanding Context (to a degree):** While many parrots are known for simply repeating sounds, some research suggests that certain species, like African Greys, can learn to associate words with objects, actions, and even emotions. They can understand that a certain sound (word) has a specific meaning in a given context.
#
# **3. Survival and Adaptation:**
#
# * **Alarm Calls:** Mimicking the alarm calls of other animals could potentially alert them to danger, although this is less documented for vocal learning in captivity.
# * **Finding Mates/Group Members:** In the wild, distinctive calls can help parrots locate their flock members or potential mates over long distances.
#
# **4. In Captivity: A Different Environment:**
#
# * **Lack of Flock:** When kept as pets, parrots are often separated from their natural flocks. Their innate drive to communicate and bond can then be directed towards their human companions.
# * **Seeking Attention and Interaction:** Talking can be a way for parrots to get attention, express needs (like hunger or a desire to play), or simply interact with their "flock" (their human family).
# * **Boredom and Stimulation:** For intelligent creatures like parrots, talking can also be a way to alleviate boredom and provide mental stimulation.
#
# **5. Individual Variation:**
#
# * **Species Differences:** Not all parrot species are equally adept at talking. African Greys, Amazons, and some Macaws are renowned for their vocal abilities.
# * **Individual Personality:** Just like humans, some individual parrots are more inclined to talk than others, regardless of species.
#
# **In summary, parrots talk because they are:**
#
# * **Highly social creatures** that rely on vocal communication for survival and bonding.
# * **Intelligent animals** with the cognitive capacity for vocal learning.
# * **Equipped with specialized vocal anatomy** that allows them to produce a wide range of sounds.
#
# When you hear a parrot talk, you're witnessing a sophisticated form of communication that stems from millions of years of evolution and a deep-seated need to connect with their social group.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')
response = model.invoke("Why langchain has separate module for multiple llms?")
response.content
# Out:
# "LangChain uses separate modules for different LLMs (e.g., `langchain-openai`, `langchain-huggingface`, `langchain-google-genai`) for several key reasons, primarily centered around **modularity, dependency management, maintainability, and user experience.**\n\nHere's a breakdown of the rationale:\n\n1.  **Dependency Management & Reduced Bloat:**\n    *   **Problem:** Different LLM providers rely on different underlying SDKs and libraries. For example, OpenAI requires the `openai` package, Hugging Face models often require `transformers` and a deep learning framework like `torch` or `tensorflow`, and Google's models need `google-generativeai`. These dependencies can be large and sometimes have conflicting versions.\n    *   **Solution:** By separating them into distinct modules, LangChain ensures that you only install the dependencies you actually need. If you're only using OpenAI, you don't need to download and install PyTorch and the entire Hugging Face `transformers` library, saving disk space, installation time, and avoiding potential dependency conflicts.\n\n2.  **Modularity & Interchangeability:**\n    *   **Core Philosophy:** LangChain's design aims to be provider-agnostic. It defines common interfaces (like `BaseLLM`, `BaseChatModel`) that all LLM implementations adhere to.\n    *   **Benefit:** Separate modules reinforce this modularity. You can swap out an `OpenAI` LLM for a `HuggingFace` LLM (or any other provider) with minimal code changes, as long as they implement the same LangChain interface. This makes your applications more flexible and resilient to changes in provider availability or pricing.\n\n3.  **Maintainability & Independent Updates:**\n    *   **API Volatility:** LLM APIs and SDKs can change frequently.\n    *   **Solution:** If all LLM integrations were bundled into a single `langchain` package, every time a specific provider (e.g., Google) updated its API, the entire `langchain` package would need to be updated and released. This could potentially introduce breaking changes or force users of other LLMs to update unnecessarily.\n    *   With separate modules, updates and bug fixes for `langchain-openai` can be released independently of `langchain-huggingface`, making maintenance more agile and targeted.\n\n4.  **Community Contributions & Ecosystem Support:**\n    *   **Specialization:** Different LLM providers have different communities and experts. Separating modules allows for easier contributions and maintenance by developers who specialize in a particular LLM ecosystem.\n    *   **Broader Reach:** It encourages more providers to integrate with LangChain, as they can contribute and maintain their specific module without affecting the core library or other integrations.\n\n5.  **Performance & Resource Efficiency:**\n    *   A smaller, more focused installation means faster `pip install` times, less disk space usage, and potentially faster startup times for applications that don't need all possible integrations loaded.\n\n6.  **Clearer API Boundaries:**\n    *   Each module has a clear, single responsibility: to provide the LangChain interface for a specific LLM provider. This makes the codebase easier to understand, navigate, and contribute to.\n\nIn essence, this modular approach allows LangChain to be both powerful and lightweight, providing a flexible framework while minimizing the overhead for individual users. You install `langchain-core` (the foundational library), `langchain-community` (common third-party integrations, including many LLMs), and then potentially specific packages like `langchain-openai` if you need the most up-to-date or specific integration for that provider."

# %%
print(response.content)
# Out:
# LangChain uses separate modules for different LLMs (e.g., `langchain-openai`, `langchain-huggingface`, `langchain-google-genai`) for several key reasons, primarily centered around **modularity, dependency management, maintainability, and user experience.**
#
# Here's a breakdown of the rationale:
#
# 1.  **Dependency Management & Reduced Bloat:**
#     *   **Problem:** Different LLM providers rely on different underlying SDKs and libraries. For example, OpenAI requires the `openai` package, Hugging Face models often require `transformers` and a deep learning framework like `torch` or `tensorflow`, and Google's models need `google-generativeai`. These dependencies can be large and sometimes have conflicting versions.
#     *   **Solution:** By separating them into distinct modules, LangChain ensures that you only install the dependencies you actually need. If you're only using OpenAI, you don't need to download and install PyTorch and the entire Hugging Face `transformers` library, saving disk space, installation time, and avoiding potential dependency conflicts.
#
# 2.  **Modularity & Interchangeability:**
#     *   **Core Philosophy:** LangChain's design aims to be provider-agnostic. It defines common interfaces (like `BaseLLM`, `BaseChatModel`) that all LLM implementations adhere to.
#     *   **Benefit:** Separate modules reinforce this modularity. You can swap out an `OpenAI` LLM for a `HuggingFace` LLM (or any other provider) with minimal code changes, as long as they implement the same LangChain interface. This makes your applications more flexible and resilient to changes in provider availability or pricing.
#
# 3.  **Maintainability & Independent Updates:**
#     *   **API Volatility:** LLM APIs and SDKs can change frequently.
#     *   **Solution:** If all LLM integrations were bundled into a single `langchain` package, every time a specific provider (e.g., Google) updated its API, the entire `langchain` package would need to be updated and released. This could potentially introduce breaking changes or force users of other LLMs to update unnecessarily.
#     *   With separate modules, updates and bug fixes for `langchain-openai` can be released independently of `langchain-huggingface`, making maintenance more agile and targeted.
#
# 4.  **Community Contributions & Ecosystem Support:**
#     *   **Specialization:** Different LLM providers have different communities and experts. Separating modules allows for easier contributions and maintenance by developers who specialize in a particular LLM ecosystem.
#     *   **Broader Reach:** It encourages more providers to integrate with LangChain, as they can contribute and maintain their specific module without affecting the core library or other integrations.
#
# 5.  **Performance & Resource Efficiency:**
#     *   A smaller, more focused installation means faster `pip install` times, less disk space usage, and potentially faster startup times for applications that don't need all possible integrations loaded.
#
# 6.  **Clearer API Boundaries:**
#     *   Each module has a clear, single responsibility: to provide the LangChain interface for a specific LLM provider. This makes the codebase easier to understand, navigate, and contribute to.
#
# In essence, this modular approach allows LangChain to be both powerful and lightweight, providing a flexible framework while minimizing the overhead for individual users. You install `langchain-core` (the foundational library), `langchain-community` (common third-party integrations, including many LLMs), and then potentially specific packages like `langchain-openai` if you need the most up-to-date or specific integration for that provider.
